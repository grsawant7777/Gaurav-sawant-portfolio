# %%
# Sequential execution

dbutils.notebook.run("/Users/gauravrsawant777@gmail.com/Healthcare_Project3/bronze_ingestion1", 0)
dbutils.notebook.run("/Users/gauravrsawant777@gmail.com/Healthcare_Project3/Silver_Transformation1", 0)
dbutils.notebook.run("/Users/gauravrsawant777@gmail.com/Healthcare_Project3/Gold_Analytics1", 0)

print("End-to-End Healthcare 360 Pipeline successfully updated and executed!")
# Out:
# End-to-End Healthcare 360 Pipeline successfully updated and executed!
